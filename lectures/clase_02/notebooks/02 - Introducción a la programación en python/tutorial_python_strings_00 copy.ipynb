# %% [markdown]
# # ¿Qué es $\mathtt{python}$?
#
# Es un lenguaje de programación orientado a objetos de propósito general, popular, fácil de usar y que posee una gran cantidad de herramientas para aprender y trabajar con machine learning.
#
# # Tutorial Básico
#
# Tutorial oficial para iniciantes [The Python Tutorial](https://docs.python.org/3/tutorial/index.html).
#
# Para cumplir los objetivos de este curso revisaremos:
#
# - Section 3: Una introducción informal a python
#     - números: `int`, `float`
#     - strings
#     - listas
# - Section 4: More Control Flow Tools
#     - `if`
#     - `for`
#     - `range`
#     - funciones
# - Section 5: Data Structures
#     - listas de comprensión
#     - tuplas
#     - diccionarios
#     - técnicas de loop

# %% [markdown]
# Creación de variables y comentarios

# %%
# primer comentario
spam = 1  # segundo comentario
          # ... tercer comentario!
text = "# esto no es un comentario porque está entre comillas."

# Imprimiendo
print(text, spam)
print(f"Yo no se si es {spam}")
# Out:
# # esto no es un comentario porque está entre comillas. 1
# Yo no se si es 1

# %%
# improviso una nueva célula

variable_1 = 1
variable_2 = 10

print(variable_1 + variable_2)
# Out:
# 11

# %% [markdown]
# Formato

# %%
texto = "no recuerdo nada de {nombre}"

# %%
texto.format(nombre="el semestre pasado")
# Out:
# 'no recuerdo nada de el semestre pasado'

# %% [markdown]
# Saltos de linea

# %%
print('C:\some\name')  # aquí \n es un salto de linea!
# Out:
# C:\some
# ame

# %%
print('C:\some\\name')  # un slash se debe anteceder para colocar caracteres especiales como este!
# Out:
# C:\some\name

# %% [markdown]
# Suma y multiplicación de strings

# %%
3 * 'un' + 'boom'
# Out:
# 'unununboom'

# %% [markdown]
# Posiciones dentro de un string

# %%
word = 'Python'

# %%
word[0]
# Out:
# 'P'

# %%
word[-1]
# Out:
# 'n'

# %%
word[-2]
# Out:
# 'o'

# %% [markdown]
# Largo de un string

# %%
s = "FacultaddeArtesdeLaUniversidaddeCHile"
print(len(s))
# Out:
# 37

# %% [markdown]
# ### ¿Por qué aprender todo esto?
# En muchas bases de datos de audio, la información de clase/target y características de un hablante vienen incorporadas dentro del nombre del archivo ```wav```o ```mp3```. Por ejemplo:
#
# ```98u12398h1297437_clase_actor.wav```
#
#
# identificador, que tag o a que clase pertenece el audio , si fue una voz de hombre o mujer, o si fue un actor etc.
