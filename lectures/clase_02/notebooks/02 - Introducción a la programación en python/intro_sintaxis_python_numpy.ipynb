# %% [markdown]
# **Revisando instrucciones básicas para trabajar DS en python 09/12/2021**
#
# Solo cubriré algunos aspectos, lo que directamente usaremos para ejemplos sencillos de DS. Para ejecutar las células debes presionar shift + Enter

# %% [markdown]
# **Operaciones básicas en $\mathtt{python}$**

# %% [markdown]
# suma

# %%
3+3
# Out:
# 6

# %% [markdown]
# multiplicación

# %%
3*3
# Out:
# 9

# %% [markdown]
# potencias

# %%
2**8
# Out:
# 256

# %% [markdown]
# división

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# división entera

# %%
3//2
# Out:
# 1

# %% [markdown]
# módulo

# %%
20%2
# Out:
# 0

# %% [markdown]
# creación de variables

# %%
x = 3
y = 4

z = x+y

print(z)
# Out:
# 7

# %% [markdown]
# **Ciclos**

# %% [markdown]
# Comenzamos por el ciclo *for*, observar que utilizamos indentación!

# %%
for i in [1,2,3]:
  print(i)
# Out:
# 1
# 2
# 3

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
x = [1,2,3]
for element in x:
  print(element)
# Out:
# 1
# 2
# 3

# %%
x = 2
for i in range(5):
  print(x+i)
# Out:
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ahora revisaremos *while*

# %%
error = 100
tau = 90

# %%
error -=1

# %%
error
# Out:
# 99

# %%
contador = 0
while error > tau:
  contador +=1
  error -= 1 
  print("iteración número: ", contador)
  print("Error:")
  print(error)
# Out:
# iteración número:  1
# Error:
# 98
# iteración número:  2
# Error:
# 97
# iteración número:  3
# Error:
# 96
# iteración número:  4
# Error:
# 95
# iteración número:  5
# Error:
# 94
# iteración número:  6
# Error:
# 93
# iteración número:  7
# Error:
# 92
# iteración número:  8
# Error:
# 91
# iteración número:  9
# Error:
# 90

# %% [markdown]
# Condiciones *if*, *break*, *pass*:

# %%
for i in range(5):
  print("iteracion: ", i)
  if i >= 2:
    print("mayor o igual que dos!")
# Out:
# iteracion:  0
# iteracion:  1
# iteracion:  2
# mayor o igual que dos!
# iteracion:  3
# mayor o igual que dos!
# iteracion:  4
# mayor o igual que dos!

# %%
for i in range(6):
  print("iteracion: ", i)
  if i >= 2 and i < 4:
    print("mayor o igual que dos!")
  elif i == 5:
    print("igual a 5!")
# Out:
# iteracion:  0
# iteracion:  1
# iteracion:  2
# mayor o igual que dos!
# iteracion:  3
# mayor o igual que dos!
# iteracion:  4
# iteracion:  5
# igual a 5!

# %%
for i in range(6):
  print("iteracion: ", i)
  if i >= 2 and i < 4:
    print("mayor o igual que dos!")
  elif i == 4:
    print("igual a 4!")
  elif i == 5:
    print("igual a 5!")
# Out:
# iteracion:  0
# iteracion:  1
# iteracion:  2
# mayor o igual que dos!
# iteracion:  3
# mayor o igual que dos!
# iteracion:  4
# igual a 4!
# iteracion:  5
# igual a 5!

# %%
for i in range(6):
  print("iteracion: ", i)
  if i >= 0 and i < 4:
    print("mayor o igual que dos!")
  else:
    print("se acabó")
    break
# Out:
# iteracion:  0
# mayor o igual que dos!
# iteracion:  1
# mayor o igual que dos!
# iteracion:  2
# mayor o igual que dos!
# iteracion:  3
# mayor o igual que dos!
# iteracion:  4
# se acabó

# %% [markdown]
# **Listas, Vectores y Matrices en $\mathtt{python}$**

# %% [markdown]
# **Listas**

# %%
# Diferentes formas de crear listas

# creando una lista vacía
lista_1 = list()

# %% [markdown]
# observando que tiene dentro

# %%
lista_1
# Out:
# []

# %% [markdown]
# ingresando elementos a la lista

# %%
lista_1.append(1)

# %% [markdown]
# revisamos

# %%
lista_1
# Out:
# [1]

# %%
print("El largo de la lista es: ")
print(len(lista_1))
# Out:
# El largo de la lista es:
# 1

# %% [markdown]
# Podemos agregar diferentes tipos de datos, por ejemplo, strings:

# %%
lista_1.append("casa")

# %%
print("El largo de la lista es: ")
print(len(lista_1))
# Out:
# El largo de la lista es:
# 2

# %%
lista_1
# Out:
# [1, 'casa']

# %% [markdown]
# para llamar elemntos de la lista, debemos tener presente que los índices comienzan en cero!

# %%
lista_1[0]
# Out:
# 1

# %%
lista_1[1]
# Out:
# 'casa'

# %% [markdown]
# otra forma de crear una lista

# %%
lista_2 = []

# %%
lista_2.append(lista_1[1])

# %%
lista_2
# Out:
# ['casa']

# %% [markdown]
# es posible realizar algunas operaciones entre listas!, por ejemplo multiplicar por un escalar

# %%
lista_2*3
# Out:
# ['casa', 'casa', 'casa']

# %% [markdown]
# sumar listas

# %%
lista_2 + lista_1
# Out:
# ['casa', 1, 'casa']

# %% [markdown]
# **Vectores**
#
# Una librería comunmente utilizada para trabajar vectores y matrices es $\mathtt{numpy}$. Es una librería orientada a este tipo de objetos y en general, a diferentes herramientas del álgebra lineal. Más adelante veremos por qué es muy necesario entender y trabajar con álgebra lineal. Entonces, ahora crearé listas de números que serán operadas bajo la perspectiva del álgebra lineal.

# %% [markdown]
# Importamos la librería (para instalarla en localmente, debemos tener python instalado y pip). Una vez instalado eso bastaría colocar en la terminal $\mathtt{pip}$ $\mathtt{install}$ $\mathtt{numpy}$

# %%
import numpy

# %% [markdown]
# Podemos crear una lista numérica, como hicimos anteriormente y "transformarla" a un vector. Para ver esta diferencia veamos el siguiente ejemplo:

# %%
x_lista = [1,2,3,-1]

# %% [markdown]
# ahora como vector:

# %%
x_vector = numpy.asarray([x_lista])

# %%
x_vector
# Out:
# array([[ 1,  2,  3, -1]])

# %% [markdown]
# sumemos ```x_lista``` con si misma:

# %%
x_lista+ x_lista
# Out:
# [1, 2, 3, -1, 1, 2, 3, -1]

# %% [markdown]
# ahora sumemos ```x_vector``` con él mismo:

# %%
x_vector + x_vector
# Out:
# array([[ 2,  4,  6, -2]])

# %% [markdown]
# creemos otro vector y restemos el vector ```x_vector``` con este nuevo elemento, para esto utilizaremos la función ```numpy.ones``` que permite crear vectores de unos, solo debemos colocar correctamente las dimensiones. El vector ```x_vector``` tiene una línea y cuatro columnas, entonces usaremos $(1,4)$:

# %%
y_vector = numpy.ones((1,4))

# %%
y_vector
# Out:
# array([[1., 1., 1., 1.]])

# %% [markdown]
# Ahora sumamos

# %%
x_vector + y_vector
# Out:
# array([[2., 3., 4., 0.]])

# %% [markdown]
# **Operaciones de álgebra lineal**

# %% [markdown]
# *Producto Interno*

# %% [markdown]
# Una operación básica es el producto punto entre dos vectores. Matemáticamente dados dos vectores $\mathbf{x}$ e $\mathbf{y}\in \mathbb{R}^{N}$ (dos vectores de dimensión $N$ o con $N$ elementos) el producto $f: \mathbb{R}^{N}\times \mathbb{R}^{N}\rightarrow \mathbb{R}$ es dado por:
#
# \begin{equation}
#   f(\mathbf{x},\mathbf{y}) = \langle \mathbf{x}, \mathbf{y} \rangle = \displaystyle \sum_{i = 1}^{N} x_{i}y_{i}
# \end{equation}
#
# que representa la multiplicación componente a componente de los elementos de los vectores $\mathbf{x}$ e $\mathbf{y}$ y luego la suma de estas multiplicaciones, por ejemplo:
#
# \begin{equation}
#   f([1,2],[-1,4]) = \langle [1,2], [-1,4]\rangle = \displaystyle \sum_{i = 1}^{N} x_{i}y_{i} = 1\cdot -1 + 2 \cdot 4 = -1 + 8 = 7
# \end{equation}
#
# comunmente se utiliza el símbolo $\langle \cdot, \cdot \rangle$

# %% [markdown]
# En $\mathtt{numpy}$ podemos calcularlo así:

# %%
numpy.dot(x_vector,x_vector.T)
# Out:
# array([[15]])

# %% [markdown]
# la función ```.T``` aplica la transposición del vector (Lo transforma en un vector columna). Esto porque, debido a las reglas del álgebra lineal, las dimensiones internas de los vectores deben ser iguales para poder aplicar esta operación, por ejemplo en este caso: $(1,\mathbf{4}) \times (\mathbf{4},1)$, los números en negrito se llaman *dimensiones internas* y ellas deben coincidir. Si no realizamos transposición tendríamos  $(1,\mathbf{4}) \times (\mathbf{1},4)$ lo que arrojaría **el siguiente error**:

# %%
numpy.dot(x_vector,x_vector)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-312096400fe0> in <module>
# ----> 1 numpy.dot(x_vector,x_vector)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (1,4) and (1,4) not aligned: 4 (dim 1) != 1 (dim 0)

# %% [markdown]
# *Tamaño o dimensión*

# %% [markdown]
# Para saber cuánto mide un vector podemos utilizar la función *shape*

# %%
x_vector.shape

# %%
y_vector.shape

# %% [markdown]
# **Matrices**

# %% [markdown]
# Las matrices son arreglos en dos dimensiones ([link](https://en.wikipedia.org/wiki/Matrix_(mathematics))). Particularmente, usaremos arreglos numéricos. Cuando las matrices tienen "profundidad" se les llama tensores, que aunque no son concretamente tensores, comparten algunas características comunes con los tensores matemáticos ([link sobre tensores](https://es.wikipedia.org/wiki/C%C3%A1lculo_tensorial)). Por ejemplo:

# %%
matriz_de_unos = numpy.ones((4,4))

# %%
matriz_de_unos

# %%
matriz_de_unos.shape

# %% [markdown]
# podemos multiplicar matrices o vectores por escalares!

# %%
matriz_de_dos = 2 * matriz_de_unos

# %%
matriz_de_dos

# %%
matriz_de_ceros = numpy.zeros((5,5))

# %%
matriz_de_ceros

# %% [markdown]
# *Suma de Matrices*

# %%
matriz_de_dos + matriz_de_unos

# %% [markdown]
# *Multiplicación de Matrices*

# %% [markdown]
# En este caso también necesitamos respetar la regla de las dimensiones internas!.
# Matemáticamente dadas dos matrices $A\in \mathbb{R}^{K\times N}$ y $B\in \mathbb{R}^{N\times D}$, el producto $g: \mathbb{R}^{K\times N}\times \mathbb{R}^{N\times D}\rightarrow {R}^{K \times D}$ es dado por:
#
# \begin{equation}
#   g\left(A,B \right) = (A B)_{ij} = \displaystyle \sum_{k = 1}^{N} a_{ik}b_{kj}
# \end{equation}
#
# para "memorizar" esta fórmula, generalmente se piensa en "multiplicar filas de la matriz $A$ por las columnas de la matriz $B$" pero esta cuando hablamos de "multiplicar" nos referimos al producto interno. Por ejemplo:

# %%
matriz_de_7 = 7*numpy.ones((6,4))

# %%
matriz_de_7.shape

# %%
matriz_de_unos.shape

# %% [markdown]
# para multiplicar utilizamos el símbolo @

# %%
multiplicacion = matriz_de_7@matriz_de_unos

# %%
multiplicacion.shape

# %% [markdown]
# ejemplo más pequeños con variedad de números

# %%
A = numpy.asarray([[1,2],[3,4]])
B = numpy.asarray([[2,-1],[-4,0]])

# %%
A

# %%
B

# %%
A@B

# %% [markdown]
# Observemos otro caso!

# %%
matriz_de_6 = 6*numpy.ones((4,4))
matriz_de_4 = 4*numpy.ones((4,4))

# %%
matriz_de_6

# %%
matriz_de_4

# %% [markdown]
# ahora usaremos el operador *

# %%
matriz_de_6 * matriz_de_4

# %% [markdown]
# Para el ejemplo anterior:

# %%
A*B

# %% [markdown]
# ¿Cuál es la diferencia entre * y @ ?

# %%
import numpy as np

# %%
A = np.array([[2,1,5],[1,2,1],[2,1,3]])
b = np.array([[20],[10],[15]])

# %%
np.linalg.inv(A)@b
# Out:
# array([[2.5],
#        [2.5],
#        [2.5]])
