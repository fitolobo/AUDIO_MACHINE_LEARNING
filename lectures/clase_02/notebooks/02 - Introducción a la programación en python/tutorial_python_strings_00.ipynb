# %% [markdown]
# # ¿Qué es $\mathtt{python}$?
#
# Es un lenguaje de programación de propósito general, popular, fácil de usar y que posee una gran cantidad de herramientas para aprender y trabajar con machine learning.
#
# # Tutorial Básico
#
# Tutorial oficial para iniciantes [The Python Tutorial](https://docs.python.org/3/tutorial/index.html).
#
# Para cumplir los objetivos de este curso revisaremos:
#
# - Section 3: Una introducción informal a python
#     - números: `int`, `float`
#     - strings
#     - listas
# - Section 4: More Control Flow Tools
#     - `if`
#     - `for`
#     - `range`
#     - funciones
# - Section 5: Data Structures
#     - listas de comprensión
#     - tuplas
#     - diccionarios
#     - técnicas de loop

# %% [markdown]
# Creación de variables y comentarios

# %%
# primer comentario
spam = 1  # segundo comentario
          # ... tercer comentario!
text = "# esto no es un comentario porque está entre comillas."

# %% [markdown]
# Algunos ejemplos sobre imprimir

# %%
print('"Isn\'t," they said.')
# Out:
# "Isn't," they said.

# %%
print('C:\some\name')  # here \n means newline!
# Out:
# C:\some
# ame

# %% [markdown]
# Multiplicación de $\mathtt{strings}$

# %%
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %% [markdown]
# Posiciones de un $\mathtt{string}$

# %%
word = 'Python'

# %%
word[0]
# Out:
# 'P'

# %%
word[-1]
# Out:
# 'n'

# %%
s = "FacultaddeArtesdeLaUniversidaddeCHile"
print(len(s))
# Out:
# 37

# %% [markdown]
# 98u12398h1297437_clase_actor.wav
#
# identificador, que tag o a que clase pertenece el audio , si fue una voz de hombre o mujer, o si fue un actor etc.
