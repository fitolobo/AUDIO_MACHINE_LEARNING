#        -9.61263599e-01, -1.45832446e+00,  4.94341651e-01, -1.49419377e+00,
#        -4.46699203e-01,  2.04377395e-01,  6.12232523e-01,  7.44884536e-01,
#        -3.62812886e-02, -8.32395348e-01,  1.92381543e+00, -6.05981321e-01,
#         1.80358898e+00, -4.52524973e-01,  1.16128569e+00,  1.06996554e+00,
#        -1.04553425e+00,  3.55284507e-01,  7.55392029e-01,  7.00982122e-01,
#        -1.98937450e-01,  3.01960045e-01, -3.94689681e-01, -1.17181338e+00,
#         9.84012237e-01, -5.59681422e-01,  1.37975819e+00,  6.02450901e-01,
#        -8.92646674e-01, -1.61198320e-01, -2.86384915e-01, -8.70887650e-01,
#         5.01429590e-01, -4.78614074e-01,  1.63169151e+00,  8.60891241e-01,
#        -8.80189065e-01, -1.90005215e-02, -2.26760192e-01, -1.56450785e+00,
#         9.31255679e-01,  9.49808815e-01,  9.25501215e-01, -4.56987858e-01,
#         1.06898597e+00, -2.09752935e-01,  9.35147780e-01,  1.81252782e+00,
#         1.40109881e-01, -1.41914878e+00, -3.16901197e-01,  6.40985866e-01,
#         1.21987438e+00, -1.13379204e+00, -1.90548298e-01,  2.33339126e-01,
#         4.34998324e-01,  9.10423603e-01, -9.48439656e-01, -4.23478297e-01,
#         1.00796648e+00,  3.92334911e-01,  4.48380651e-01,  1.12532350e+00,
#         1.04053390e-01,  5.28003422e-01, -3.14563862e-01, -1.34501002e+00,
#        -1.29525789e+00,  7.43205537e-02, -1.99560718e-01, -6.54603169e-01,
#         3.18014296e-01, -8.90271552e-01,  1.11337266e-01, -1.95225583e-02,
#        -8.39988915e-01, -2.29820588e+00,  1.45652739e+00,  3.16637236e-01,
#        -2.66412594e+00, -4.26428618e-01,  3.93787731e-01, -2.28140691e-01,
#         5.80330113e-01, -9.73267585e-01,  1.75167729e-01, -5.34836927e-02,
#        -1.83061987e-01, -2.21028902e-01,  1.99759555e-01,  9.32721414e-01,
#        -5.30119800e-01, -4.07240024e-01,  1.60564992e-01, -1.20149976e-01,
#         3.85602292e-01,  7.18290736e-01,  1.29118890e+00, -1.16444148e-01,
#        -2.27729800e+00, -6.96245395e-02,  3.53870427e-01, -1.86955017e-01])

# %%
def standard_normal_mi_version_charcha(x: np.array, sigma = 1, mu = 0):
    f = 1/(sigma*np.sqrt(2*np.pi)) * (-0.5*np.exp((x-mu/sigma)**2))
    return f

# %%
standard_normal_mi_version_charcha(x = np.array([1,2,3,4,5,6]))
# Out:
# array([-5.42218776e-01, -1.08907552e+01, -1.61633139e+03, -1.77252260e+06,
#        -1.43628994e+10, -8.59966272e+14])

# %%
help(np.random.randn)
# Out:
# Help on built-in function randn:
#
# randn(...) method of numpy.random.mtrand.RandomState instance
#     randn(d0, d1, ..., dn)
#
#     Return a sample (or samples) from the "standard normal" distribution.
#
#     .. note::
#         This is a convenience function for users porting code from Matlab,
#         and wraps `standard_normal`. That function takes a
#         tuple to specify the size of the output, which is consistent with
#         other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
#     .. note::
#         New code should use the
#         `~numpy.random.Generator.standard_normal`
#         method of a `~numpy.random.Generator` instance instead;
#         please see the :ref:`random-quick-start`.
#
#     If positive int_like arguments are provided, `randn` generates an array
#     of shape ``(d0, d1, ..., dn)``, filled
#     with random floats sampled from a univariate "normal" (Gaussian)
#     distribution of mean 0 and variance 1. A single float randomly sampled
#     from the distribution is returned if no argument is provided.
#
#     Parameters
#     ----------
#     d0, d1, ..., dn : int, optional
#         The dimensions of the returned array, must be non-negative.
#         If no argument is given a single Python float is returned.
#
#     Returns
#     -------
#     Z : ndarray or float
#         A ``(d0, d1, ..., dn)``-shaped array of floating-point samples from
#         the standard normal distribution, or a single such float if
#         no parameters were supplied.
#
#     See Also
#     --------
#     standard_normal : Similar, but takes a tuple as its argument.
#     normal : Also accepts mu and sigma arguments.
#     random.Generator.standard_normal: which should be used for new code.
#
#     Notes
#     -----
#     For random samples from the normal distribution with mean ``mu`` and
#     standard deviation ``sigma``, use::
#
#         sigma * np.random.randn(...) + mu
#
#     Examples
#     --------
#     >>> np.random.randn()
#     2.1923875335537315  # random
#
#     Two-by-four array of samples from the normal distribution with
#     mean 3 and standard deviation 2.5:
#
#     >>> 3 + 2.5 * np.random.randn(2, 4)
#     array([[-4.49401501,  4.00950034, -1.81814867,  7.29718677],   # random
#            [ 0.39924804,  4.68456316,  4.99394529,  4.84057254]])  # random

# %% [markdown]
# ### Preguntas sobre Gradiente Descendiente :D

# %%
def calculo_de_derivadas(x, y, theta_1, theta_0):
    """
    Cálculo del gradiente para el problema de regresión lineal.
    Argumentos:
      x (ndarray (n,)): datos, n ejemplos
      y (ndarray (n,)): valores objetivos
      theta_1,theta_0 (escalares)    : parámetros del modelo
    Returna
      dj_d_theta_1 (escalar): gradiente de la función de perdida para el parámetro theta_1 respecto de la data de entrenamiento.
      dj_d_theta_0 (escalar): gradiente de la función de perdida para el parámetro theta_0 respecto de la data de entrenamiento.
     """

    # Número de ejemplos de entrenamiento
    n = x.shape[0]
    # Inicializando los gradientes en cero
    dj_d_theta_1 = 0
    dj_d_theta_0 = 0

    # cálculo de los gradientes
    for i in range(n):
        g_theta = theta_1 * x[i] + theta_0
        dj_d_theta_1_i = (g_theta - y[i]) * x[i]
        dj_d_theta_0_i = g_theta - y[i]
        dj_d_theta_1 += dj_d_theta_1_i
        dj_d_theta_0 += dj_d_theta_0_i
    dj_d_theta_1 = dj_d_theta_1 / n
    dj_d_theta_0 = dj_d_theta_0 / n

    return dj_d_theta_1, dj_d_theta_0

# %%
def funcion_de_perdida(x: np.array, y: np.array, theta_1: float, theta_0: float):
    '''
      Función que calcula el valor de pérdida/costo asociado al modelo.
      También conocido como error cuadrático.
    '''
    n = x.shape[0]
    perdida = 0

    for i in range(n):
        q_theta = theta_1 * x[i] + theta_0
        perdida = perdida + (q_theta - y[i])**2 # acumulo el valor de pérdida
    perdida_total = 1 / (2 * n) * perdida

    return perdida_total

# %%
import math 
def gradiente_estocastico(theta_1,theta_0,x,y):
    dj_d_theta_0 = (((theta_1 * x + theta_0)) - y)
    dj_d_theta_1 = ((theta_1 * x + theta_0)- y) * x
    return dj_d_theta_0,dj_d_theta_1

def gradiente_descendiente(x, y, theta_1_in, theta_0_in, alpha, num_iters, funcion_de_perdida, calculo_de_derivadas):
    """
    Realiza el Gradiente Descendiente para calcular theta_1 y theta_0. Actualiza los valores theta_1,theta_0
    realizando num_iters pasos de gradiente con una tasa de aprendizaje alpha

    Argumentos:
      x (ndarray (n,))  : Datos, n ejemplos
      y (ndarray (n,))  : valores objetivo
      theta_1_in,theta_0_in (scalar): valores iniciales de los parámetros.
      alpha (float):     tasa de aprendizaje
      num_iters (int):   número de iteraciones del gradiente descendiente.
      funcion_de_perdida:     funcion_de_perdida.
      calculo_de_derivadas: cálculo de derivadas.

    Returna:
      theta_1 (escalar): valor actualizado del parámetro tras correr el gradiente
      theta_0 (escalar): valor actualizado del parámetro tras correr el gradiente
      J_historia (List): historia de los valores de pérdida
      p_historia (List): historia de los parámetros actualizados [theta_1,theta_0]
      """

    # An array to store cost J and w's at each iteration primarily for graphing later
    J_historia = []
    theta_historia = []
    theta_0 = theta_0_in
    theta_1 = theta_1_in

    for i in range(num_iters):
        for i in range(len(x)):
            # Calculamos el gradiente de los parámetros
            #dj_d_theta_1, dj_d_theta_0 = calculo_de_derivadas(x[i], y[i], theta_1 , theta_0)

            # actualizamos los parámetros utilizando las ecuaciones
            dj_d_theta_0,dj_d_theta_1 = gradiente_estocastico(theta_1,theta_0,x[i],y[i])
            theta_0= theta_0 - alpha *  dj_d_theta_0
            theta_1 = theta_1 - alpha *  dj_d_theta_1 

            # salvamos la pérdida en cada iteración
            if i%3 == 0:      # prevenimos un número de iteraciones mayores a 100K
                J_historia.append(funcion_de_perdida(x, y, theta_1 , theta_0))
                theta_historia.append([theta_1,theta_0])
            # Si hay menos de 10 iteraciones imprimimos cada valor obtenido, en caso contrario cada 10 iteraciones.
            if i% math.ceil(num_iters/10) == 0:
                print(f"Iteration {i:4}: Cost {J_historia[-1]:0.2e} ",
                    f"dj_d_theta_1: {dj_d_theta_1: 0.3e}, dj_d_theta_0: {dj_d_theta_0: 0.3e}  ",
                    f"theta_1: {theta_1: 0.3e}, theta_0:{theta_0: 0.5e}")

    return theta_1, theta_0, J_historia, theta_historia #retornamos los parámetros, las historias para poder graficar.

# %% [markdown]
# ### Primera iteración

# %%
x_train = np.array([1,2,3])
y_train = np.array([1,0.5,2])

x_validation= np.array([1,1,2.9])
y_validation = np.array([2,0.3,1.8])

# %%
theta_0 = 0
theta_1 = 0

print("Error (Cost) Train", funcion_de_perdida(x_train, y_train, theta_1, theta_0))
print("Error (Cost) Validation", funcion_de_perdida(x_validation, y_validation, theta_1, theta_0))
# Out:
# Error (Cost) Train 0.875
# Error (Cost) Validation 1.2216666666666667

# %%
d_theta_1, d_theta_0 = calculo_de_derivadas(x_train, y_train, theta_1, theta_0)
print("d_theta_0", d_theta_0)
print("d_theta_1", d_theta_1)
# Out:
# d_theta_0 -1.1666666666666667
# d_theta_1 -2.6666666666666665

# %%
alpha = 0.1 #hiperparametro

# %%
theta_0 = theta_0 -alpha*d_theta_0
theta_1 = theta_1 -alpha*d_theta_1
print("theta 0 nuevo:", theta_0)
print("theta 1 nuevo:", theta_1)
print("Error (Cost) Train", funcion_de_perdida(x_train, y_train, theta_1, theta_0))
print("Error (Cost) Validation", funcion_de_perdida(x_validation, y_validation, theta_1, theta_0))
# Out:
# theta 0 nuevo: 0.11666666666666668
# theta 1 nuevo: 0.26666666666666666
# Error (Cost) Train 0.26273148148148145
# Error (Cost) Validation 0.574775925925926

# %% [markdown]
# ### Segunda Iteración

# %%
d_theta_1, d_theta_0 = calculo_de_derivadas(x_train, y_train, theta_1, theta_0)
print("d_theta_0", d_theta_0)
print("d_theta_1", d_theta_1)
# Out:
# d_theta_0 -0.5166666666666666
# d_theta_1 -1.1888888888888889

# %%
theta_0 = theta_0 -alpha*d_theta_0
theta_1 = theta_1 -alpha*d_theta_1
print("theta 0 nuevo:", theta_0)
print("theta 1 nuevo:", theta_1)
print("Error (Cost) Train", funcion_de_perdida(x_train, y_train, theta_1, theta_0))
print("Error (Cost) Validation", funcion_de_perdida(x_validation, y_validation, theta_1, theta_0))
# Out:
# theta 0 nuevo: 0.16833333333333333
# theta 1 nuevo: 0.38555555555555554
# Error (Cost) Train 0.1412919238683127
# Error (Cost) Validation 0.4032393703703705

# %% [markdown]
# ### Usemos el gradiente

# %%
# inicializando los parámetros theta
theta_0_init = 0
theta_1_init = 0
# algunas configuraciones del algoritmo
iterations = 100
tmp_alpha = 1.0e-2
# run gradient descent
theta_1, theta_0, J_historia, theta_historia = gradiente_descendiente(x_train ,y_train, theta_1_init, theta_0_init, tmp_alpha,
                                                    iterations, funcion_de_perdida, calculo_de_derivadas)
print(f"(theta_1,theta_0) found by gradient descent: ({theta_1:8.4f},{theta_0:8.4f})")
# Out:
# Iteration    0: Cost 8.37e-01  dj_d_theta_1: -1.000e+00, dj_d_theta_0: -1.000e+00   theta_1:  1.000e-02, theta_0: 1.00000e-02
# Iteration    0: Cost 6.21e-01  dj_d_theta_1: -8.888e-01, dj_d_theta_0: -8.888e-01   theta_1:  8.610e-02, theta_0: 4.28592e-02
# Iteration    0: Cost 4.69e-01  dj_d_theta_1: -7.953e-01, dj_d_theta_0: -7.953e-01   theta_1:  1.501e-01, theta_0: 7.04508e-02
# Iteration    0: Cost 3.61e-01  dj_d_theta_1: -7.167e-01, dj_d_theta_0: -7.167e-01   theta_1:  2.040e-01, theta_0: 9.36127e-02
# Iteration    0: Cost 2.86e-01  dj_d_theta_1: -6.507e-01, dj_d_theta_0: -6.507e-01   theta_1:  2.493e-01, theta_0: 1.13049e-01
# Iteration    0: Cost 2.33e-01  dj_d_theta_1: -5.951e-01, dj_d_theta_0: -5.951e-01   theta_1:  2.874e-01, theta_0: 1.29353e-01
# Iteration    0: Cost 1.96e-01  dj_d_theta_1: -5.484e-01, dj_d_theta_0: -5.484e-01   theta_1:  3.195e-01, theta_0: 1.43023e-01
# Iteration    0: Cost 1.70e-01  dj_d_theta_1: -5.092e-01, dj_d_theta_0: -5.092e-01   theta_1:  3.465e-01, theta_0: 1.54477e-01
# Iteration    0: Cost 1.52e-01  dj_d_theta_1: -4.762e-01, dj_d_theta_0: -4.762e-01   theta_1:  3.692e-01, theta_0: 1.64068e-01
# Iteration    0: Cost 1.39e-01  dj_d_theta_1: -4.485e-01, dj_d_theta_0: -4.485e-01   theta_1:  3.883e-01, theta_0: 1.72093e-01
# Iteration    0: Cost 1.30e-01  dj_d_theta_1: -4.253e-01, dj_d_theta_0: -4.253e-01   theta_1:  4.045e-01, theta_0: 1.78801e-01
# Iteration    0: Cost 1.24e-01  dj_d_theta_1: -4.057e-01, dj_d_theta_0: -4.057e-01   theta_1:  4.180e-01, theta_0: 1.84400e-01
# Iteration    0: Cost 1.20e-01  dj_d_theta_1: -3.893e-01, dj_d_theta_0: -3.893e-01   theta_1:  4.294e-01, theta_0: 1.89069e-01
# Iteration    0: Cost 1.17e-01  dj_d_theta_1: -3.755e-01, dj_d_theta_0: -3.755e-01   theta_1:  4.391e-01, theta_0: 1.92954e-01
# Iteration    0: Cost 1.15e-01  dj_d_theta_1: -3.639e-01, dj_d_theta_0: -3.639e-01   theta_1:  4.472e-01, theta_0: 1.96180e-01
# Iteration    0: Cost 1.14e-01  dj_d_theta_1: -3.542e-01, dj_d_theta_0: -3.542e-01   theta_1:  4.540e-01, theta_0: 1.98853e-01
# Iteration    0: Cost 1.13e-01  dj_d_theta_1: -3.461e-01, dj_d_theta_0: -3.461e-01   theta_1:  4.598e-01, theta_0: 2.01061e-01
# Iteration    0: Cost 1.12e-01  dj_d_theta_1: -3.392e-01, dj_d_theta_0: -3.392e-01   theta_1:  4.647e-01, theta_0: 2.02877e-01
# Iteration    0: Cost 1.12e-01  dj_d_theta_1: -3.335e-01, dj_d_theta_0: -3.335e-01   theta_1:  4.688e-01, theta_0: 2.04365e-01
# Iteration    0: Cost 1.12e-01  dj_d_theta_1: -3.288e-01, dj_d_theta_0: -3.288e-01   theta_1:  4.722e-01, theta_0: 2.05576e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.248e-01, dj_d_theta_0: -3.248e-01   theta_1:  4.752e-01, theta_0: 2.06555e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.214e-01, dj_d_theta_0: -3.214e-01   theta_1:  4.777e-01, theta_0: 2.07338e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.186e-01, dj_d_theta_0: -3.186e-01   theta_1:  4.798e-01, theta_0: 2.07957e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.163e-01, dj_d_theta_0: -3.163e-01   theta_1:  4.816e-01, theta_0: 2.08439e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.144e-01, dj_d_theta_0: -3.144e-01   theta_1:  4.831e-01, theta_0: 2.08804e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.128e-01, dj_d_theta_0: -3.128e-01   theta_1:  4.844e-01, theta_0: 2.09073e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.114e-01, dj_d_theta_0: -3.114e-01   theta_1:  4.855e-01, theta_0: 2.09260e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.104e-01, dj_d_theta_0: -3.104e-01   theta_1:  4.865e-01, theta_0: 2.09378e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.095e-01, dj_d_theta_0: -3.095e-01   theta_1:  4.873e-01, theta_0: 2.09439e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.087e-01, dj_d_theta_0: -3.087e-01   theta_1:  4.880e-01, theta_0: 2.09452e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.081e-01, dj_d_theta_0: -3.081e-01   theta_1:  4.886e-01, theta_0: 2.09424e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.077e-01, dj_d_theta_0: -3.077e-01   theta_1:  4.891e-01, theta_0: 2.09362e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.073e-01, dj_d_theta_0: -3.073e-01   theta_1:  4.896e-01, theta_0: 2.09273e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.070e-01, dj_d_theta_0: -3.070e-01   theta_1:  4.900e-01, theta_0: 2.09159e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.068e-01, dj_d_theta_0: -3.068e-01   theta_1:  4.904e-01, theta_0: 2.09026e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.066e-01, dj_d_theta_0: -3.066e-01   theta_1:  4.907e-01, theta_0: 2.08876e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.065e-01, dj_d_theta_0: -3.065e-01   theta_1:  4.910e-01, theta_0: 2.08713e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.064e-01, dj_d_theta_0: -3.064e-01   theta_1:  4.912e-01, theta_0: 2.08538e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.063e-01, dj_d_theta_0: -3.063e-01   theta_1:  4.914e-01, theta_0: 2.08354e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.063e-01, dj_d_theta_0: -3.063e-01   theta_1:  4.916e-01, theta_0: 2.08162e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.063e-01, dj_d_theta_0: -3.063e-01   theta_1:  4.918e-01, theta_0: 2.07963e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.063e-01, dj_d_theta_0: -3.063e-01   theta_1:  4.920e-01, theta_0: 2.07760e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.064e-01, dj_d_theta_0: -3.064e-01   theta_1:  4.922e-01, theta_0: 2.07551e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.064e-01, dj_d_theta_0: -3.064e-01   theta_1:  4.923e-01, theta_0: 2.07340e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.065e-01, dj_d_theta_0: -3.065e-01   theta_1:  4.925e-01, theta_0: 2.07126e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.066e-01, dj_d_theta_0: -3.066e-01   theta_1:  4.926e-01, theta_0: 2.06909e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.067e-01, dj_d_theta_0: -3.067e-01   theta_1:  4.928e-01, theta_0: 2.06691e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.068e-01, dj_d_theta_0: -3.068e-01   theta_1:  4.929e-01, theta_0: 2.06471e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.069e-01, dj_d_theta_0: -3.069e-01   theta_1:  4.930e-01, theta_0: 2.06250e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.070e-01, dj_d_theta_0: -3.070e-01   theta_1:  4.931e-01, theta_0: 2.06029e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.071e-01, dj_d_theta_0: -3.071e-01   theta_1:  4.932e-01, theta_0: 2.05807e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.072e-01, dj_d_theta_0: -3.072e-01   theta_1:  4.934e-01, theta_0: 2.05585e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.073e-01, dj_d_theta_0: -3.073e-01   theta_1:  4.935e-01, theta_0: 2.05363e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.074e-01, dj_d_theta_0: -3.074e-01   theta_1:  4.936e-01, theta_0: 2.05141e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.075e-01, dj_d_theta_0: -3.075e-01   theta_1:  4.937e-01, theta_0: 2.04920e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.077e-01, dj_d_theta_0: -3.077e-01   theta_1:  4.938e-01, theta_0: 2.04698e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.078e-01, dj_d_theta_0: -3.078e-01   theta_1:  4.939e-01, theta_0: 2.04477e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.079e-01, dj_d_theta_0: -3.079e-01   theta_1:  4.940e-01, theta_0: 2.04256e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.080e-01, dj_d_theta_0: -3.080e-01   theta_1:  4.941e-01, theta_0: 2.04036e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.081e-01, dj_d_theta_0: -3.081e-01   theta_1:  4.942e-01, theta_0: 2.03816e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.083e-01, dj_d_theta_0: -3.083e-01   theta_1:  4.943e-01, theta_0: 2.03597e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.084e-01, dj_d_theta_0: -3.084e-01   theta_1:  4.944e-01, theta_0: 2.03379e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.085e-01, dj_d_theta_0: -3.085e-01   theta_1:  4.945e-01, theta_0: 2.03161e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.086e-01, dj_d_theta_0: -3.086e-01   theta_1:  4.946e-01, theta_0: 2.02944e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.088e-01, dj_d_theta_0: -3.088e-01   theta_1:  4.947e-01, theta_0: 2.02727e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.089e-01, dj_d_theta_0: -3.089e-01   theta_1:  4.948e-01, theta_0: 2.02511e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.090e-01, dj_d_theta_0: -3.090e-01   theta_1:  4.949e-01, theta_0: 2.02296e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.091e-01, dj_d_theta_0: -3.091e-01   theta_1:  4.950e-01, theta_0: 2.02082e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.092e-01, dj_d_theta_0: -3.092e-01   theta_1:  4.951e-01, theta_0: 2.01868e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.094e-01, dj_d_theta_0: -3.094e-01   theta_1:  4.952e-01, theta_0: 2.01655e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.095e-01, dj_d_theta_0: -3.095e-01   theta_1:  4.953e-01, theta_0: 2.01443e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.096e-01, dj_d_theta_0: -3.096e-01   theta_1:  4.954e-01, theta_0: 2.01232e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.097e-01, dj_d_theta_0: -3.097e-01   theta_1:  4.954e-01, theta_0: 2.01021e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.098e-01, dj_d_theta_0: -3.098e-01   theta_1:  4.955e-01, theta_0: 2.00811e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.100e-01, dj_d_theta_0: -3.100e-01   theta_1:  4.956e-01, theta_0: 2.00602e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.101e-01, dj_d_theta_0: -3.101e-01   theta_1:  4.957e-01, theta_0: 2.00394e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.102e-01, dj_d_theta_0: -3.102e-01   theta_1:  4.958e-01, theta_0: 2.00186e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.103e-01, dj_d_theta_0: -3.103e-01   theta_1:  4.959e-01, theta_0: 1.99979e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.104e-01, dj_d_theta_0: -3.104e-01   theta_1:  4.960e-01, theta_0: 1.99773e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.106e-01, dj_d_theta_0: -3.106e-01   theta_1:  4.961e-01, theta_0: 1.99568e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.107e-01, dj_d_theta_0: -3.107e-01   theta_1:  4.962e-01, theta_0: 1.99363e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.108e-01, dj_d_theta_0: -3.108e-01   theta_1:  4.963e-01, theta_0: 1.99159e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.109e-01, dj_d_theta_0: -3.109e-01   theta_1:  4.964e-01, theta_0: 1.98956e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.110e-01, dj_d_theta_0: -3.110e-01   theta_1:  4.964e-01, theta_0: 1.98754e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.111e-01, dj_d_theta_0: -3.111e-01   theta_1:  4.965e-01, theta_0: 1.98552e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.113e-01, dj_d_theta_0: -3.113e-01   theta_1:  4.966e-01, theta_0: 1.98351e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.114e-01, dj_d_theta_0: -3.114e-01   theta_1:  4.967e-01, theta_0: 1.98151e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.115e-01, dj_d_theta_0: -3.115e-01   theta_1:  4.968e-01, theta_0: 1.97951e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.116e-01, dj_d_theta_0: -3.116e-01   theta_1:  4.969e-01, theta_0: 1.97752e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.117e-01, dj_d_theta_0: -3.117e-01   theta_1:  4.970e-01, theta_0: 1.97554e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.118e-01, dj_d_theta_0: -3.118e-01   theta_1:  4.971e-01, theta_0: 1.97357e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.119e-01, dj_d_theta_0: -3.119e-01   theta_1:  4.971e-01, theta_0: 1.97161e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.120e-01, dj_d_theta_0: -3.120e-01   theta_1:  4.972e-01, theta_0: 1.96965e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.122e-01, dj_d_theta_0: -3.122e-01   theta_1:  4.973e-01, theta_0: 1.96770e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.123e-01, dj_d_theta_0: -3.123e-01   theta_1:  4.974e-01, theta_0: 1.96575e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.124e-01, dj_d_theta_0: -3.124e-01   theta_1:  4.975e-01, theta_0: 1.96382e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.125e-01, dj_d_theta_0: -3.125e-01   theta_1:  4.976e-01, theta_0: 1.96189e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.126e-01, dj_d_theta_0: -3.126e-01   theta_1:  4.977e-01, theta_0: 1.95996e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.127e-01, dj_d_theta_0: -3.127e-01   theta_1:  4.977e-01, theta_0: 1.95805e-01
# Iteration    0: Cost 1.11e-01  dj_d_theta_1: -3.128e-01, dj_d_theta_0: -3.128e-01   theta_1:  4.978e-01, theta_0: 1.95614e-01
# (theta_1,theta_0) found by gradient descent: (  0.4948,  0.1923)
